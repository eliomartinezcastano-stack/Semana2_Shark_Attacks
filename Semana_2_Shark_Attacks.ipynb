# %%
import pandas as pd

# %%
url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
Shark_Attacks_df = pd.read_excel(url)

# %%
Shark_Attacks_df.head()
# Out:
#             Date    Year        Type            Country  \
# 0   10th January  2026.0  Unprovoked          Australia
# 1    8th January  2026.0  Unprovoked  US Virgin Islands
# 2   3rd January   2026.0  Unprovoked      New Caledonia
# 3  21st December  2025.0  Unprovoked                USA
# 4  12th December  2025.0  Unprovoked                USA
#
#                           State                     Location      Activity  \
# 0                           NSW                 Avalon Beach       Surfing
# 1  Fredricksted Island St Croix                 Dorsch Beach    Snorkeling
# 2                          Kélé  Between Bourail and Moindou  Scuba Diving
# 3                    California   Lovers Point Pacific Grove      Swimming
# 4      Sonoma County California                 Salmon Creek       Surfing
#
#             Name Sex Age  ...                     Species   \
# 0   Paul Stanton   M   ?  ...                      Unknown
# ...

# %%
Shark_Attacks_df.tail()
# Out:
#              Date  Year        Type             Country              State  \
# 7060  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7061  Before 1903   0.0  Unprovoked           AUSTRALIA  Western Australia
# 7062    1900-1905   0.0  Unprovoked                 USA     North Carolina
# 7063    1883-1889   0.0  Unprovoked              PANAMA                NaN
# 7064    1845-1853   0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 7060                          Roebuck Bay        Diving
# 7061                                  NaN  Pearl diving
# 7062                       Ocracoke Inlet      Swimming
# 7063                 Panama Bay 8ºN, 79ºW           NaN
# 7064  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  ... Species   \
# 7060                   male   M  NaN  ...      NaN
# 7061                  Ahmun   M  NaN  ...      NaN
# ...

# %%
Shark_Attacks_df.shape
# Out:
# (7065, 23)

# %%
Shark_Attacks_df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
Shark_Attacks_df.dtypes
# Out:
# Date               object
# Year              float64
# Type               object
# Country            object
# State              object
# Location           object
# Activity           object
# Name               object
# Sex                object
# Age                object
# Injury             object
# Fatal Y/N          object
# Time               object
# Species            object
# Source             object
# pdf                object
# href formula       object
# href               object
# Case Number        object
# Case Number.1      object
# original order    float64
# Unnamed: 21        object
# Unnamed: 22        object
# dtype: object

# %%
Shark_Attacks_df.nunique()
# Out:
# Date              6107
# Year               261
# Type                13
# Country            251
# State              944
# Location          4611
# Activity          1609
# Name              5785
# Sex                 10
# Age                251
# Injury            4179
# Fatal Y/N           12
# Time               469
# Species           1736
# Source            5399
# pdf               6789
# href formula      6784
# href              6776
# Case Number       6777
# Case Number.1     6775
# original order    6797
# Unnamed: 21          1
# Unnamed: 22          2
# dtype: int64

# %%
for columna in Shark_Attacks_df.columns:
    print(f"Valores únicos por columna: {columna}")
    print(Shark_Attacks_df[columna].unique())
    print("-" *30)
# Out:
# Valores únicos por columna: Date
# ['10th January' '8th January' '3rd January ' ... '1900-1905' '1883-1889'
#  '1845-1853']
# ------------------------------
# Valores únicos por columna: Year
# [2026. 2025. 2024. 2023. 2022. 2021. 2020. 2019. 2018. 2017.   nan 2016.
#  2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008. 2007. 2006. 2005. 2004.
#  2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996. 1995. 1984. 1994. 1993.
#  1992. 1991. 1990. 1989. 1969. 1988. 1987. 1986. 1985. 1983. 1982. 1981.
#  1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973. 1972. 1971. 1970. 1968.
#  1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960. 1959. 1958. 1957. 1956.
#  1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948. 1848. 1947. 1946. 1945.
#  1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937. 1936. 1935. 1934. 1933.
#  1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925. 1924. 1923. 1922. 1921.
#  1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913. 1912. 1911. 1910. 1909.
# ...

# %%
Shark_Attacks_df['Fatal Y/N'].unique()
# Out:
# array(['N', 'Y', 'F', 'M', nan, 'n', 'Nq', 'UNKNOWN', 2017, 'Y x 2', ' N',
#        'N ', 'y'], dtype=object)

# %%
print(f"El dataset tiene {Shark_Attacks_df.shape[0]} filas y {Shark_Attacks_df.shape[1]} columnas.")
print(Shark_Attacks_df.columns)
# Out:
# El dataset tiene 7065 filas y 23 columnas.
# Index(['Date', 'Year', 'Type', 'Country', 'State', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal Y/N', 'Time', 'Species ',
#        'Source', 'pdf', 'href formula', 'href', 'Case Number', 'Case Number.1',
#        'original order', 'Unnamed: 21', 'Unnamed: 22'],
#       dtype='object')

# %%
Ataques_por_pais = Shark_Attacks_df["Country"].value_counts()
Ataques_por_pais
# Out:
# Country
# USA                   2578
# AUSTRALIA             1482
# SOUTH AFRICA           597
# NEW ZEALAND            144
# PAPUA NEW GUINEA       136
#                       ...
# GRAND CAYMAN             1
# ST. MAARTIN              1
# US Virgin Islands        1
# GULF OF ADEN             1
# CEYLON (SRI LANKA)       1
# Name: count, Length: 251, dtype: int64

# %%
Shark_Attacks_df.describe()
# Out:
#               Year  original order
# count  7063.000000     6799.000000
# mean   1935.890981     3401.152081
# std     270.825801     1963.076319
# min       0.000000        2.000000
# 25%    1948.000000     1701.500000
# 50%    1986.000000     3401.000000
# 75%    2010.000000     5100.500000
# max    2026.000000     6802.000000
